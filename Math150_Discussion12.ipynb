# %% [markdown]
# Math 150 disscussion worksheet 12: Brianne Rouleau, Karl Angelo Lerum, Jairo Carreon, Tommy Truong

# %% [markdown]
# Last edit: May 20 2021

# %% [markdown]
# Q1

# %% [markdown]
# ![figure1.PNG](attachment:figure1.PNG)

# %% [markdown]
# Q2

# %% [markdown]
# ![figure2.PNG](attachment:figure2.PNG)

# %% [markdown]
# Q3

# %% [markdown]
# $P=\begin{matrix}
# m_{0,0} & p_{0,0} & 0 & q_{0,0}&0&0&0&0&0\\
# r_{1,0} & m_{1,0} & p_{1,0} &0& q_{1,0}&0&0&0&0\\
# 0&r_{2,0} & m_{2,0} &0&0& q_{2,0}&0&0&0\\
# s_{0,1}&0&0&m_{0,1} & p_{0,1} &0& q_{0,1}&0&0\\
# 0&s_{1,1}&0&r_{1,1} & m_{1,1} & p_{1,1} &0& q_{1,1}&0\\
# 0&0&s_{2,1}&0&r_{2,1} & m_{2,1} &0 &0& q_{2,1}\\
# 0&0&0&s_{0,2}&0&0 & m_{0,2} & p_{0,2} &0\\
# 0&0&0&0&s_{1,2}&0&r_{1,2} & m_{1,2}&p_{1,2}\\
# 0&0&0&0&0&s_{2,2}&0&r_{2,2} & m_{2,2}
# \end{matrix}$

# %% [markdown]
# Q4

# %%
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from numpy import linalg as LA
p = np.matrix([[.1,.3,0,.6,0,0,0,0,0],
                       [.5,.25,.05,0,.2,0,0,0,0],
                        [0,.4,.3,0,0,.3,0,0,0],
                        [.15,0,0,.15,.35,0,.35,0,0],
                        [0,0.05,0,.45,.1,.2,0,.2,0],
                        [0,0,.45,0,.15,.2,0,0,.2],
                        [0,0,0,.7,0,0,.15,.15,0],
                        [0,0,0,0,.4,0,.2,.2,.2],
                        [0,0,0,0,0,.5,0,.25,.25]])
v1 = np.matrix([0.25,0.25,0.05,0.05,0.05,0.05,.05,.05,.2])
v2 = np.matrix([0.05,0.45,0.1,.05,.05,.1,.1,0.1,.1])
v3 = np.matrix([0.05,0.2,0.05,0.15,0.05,.05,.25,.01,.19])
x=v1
for i in range(100):
    x=x*p
print("Trial 1")
print('intial')
print(v1)
print('distribution')
print(x)
x=v2
for i in range(100):
    x=x*p
print("Trial 2")
print('intial')
print(v2)
print('distribution')
print(x)
x=v3
for i in range(100):
    x=x*p
print("Trial 3")
print('intial')
print(v3)
print('distribution')
print(x)
print("distribution of p^100")
x=p**100
print(x)
# Out:
# Trial 1
# intial
# [[0.25 0.25 0.05 0.05 0.05 0.05 0.05 0.05 0.2 ]]
# distribution
# [[0.08753213 0.08239177 0.06795249 0.25055355 0.16706381 0.09654923
#   0.1218179  0.07925736 0.04688176]]
# Trial 2
# intial
# [[0.05 0.45 0.1  0.05 0.05 0.1  0.1  0.1  0.1 ]]
# distribution
# [[0.09628534 0.09063094 0.07474774 0.27560891 0.18377019 0.10620416
#   0.13399969 0.08718309 0.05156993]]
# Trial 3
# intial
# [[0.05 0.2  0.05 0.15 0.05 0.05 0.25 0.01 0.19]]
# distribution
# [[0.08753213 0.08239177 0.06795249 0.25055355 0.16706381 0.09654923
#   0.1218179  0.07925736 0.04688176]]
# distribution of p^100
# [[0.08753213 0.08239177 0.06795249 0.25055355 0.16706381 0.09654923
#   0.1218179  0.07925736 0.04688176]
#  [0.08753213 0.08239177 0.06795249 0.25055355 0.16706381 0.09654923
#   0.1218179  0.07925736 0.04688176]
#  [0.08753213 0.08239177 0.06795249 0.25055355 0.16706381 0.09654923
#   0.1218179  0.07925736 0.04688176]
#  [0.08753213 0.08239177 0.06795249 0.25055355 0.16706381 0.09654923
# ...
